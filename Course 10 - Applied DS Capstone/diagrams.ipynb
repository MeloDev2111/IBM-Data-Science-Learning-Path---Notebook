# %%
from diagrams import Diagram, Cluster, Edge
from diagrams.aws.compute import EC2
from diagrams.aws.network import ELB
from diagrams.aws.database import RDS
from diagrams.programming.language import Python 
from diagrams.generic.database import SQL
from diagrams.onprem.compute import Server
from diagrams.generic.network import Firewall, Switch, Router
from diagrams.generic.storage import Storage  


import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

with Diagram("img/Data Collection", show=True):
    
    d3 = Storage("Consolidated dataset")
    

    with Cluster("API Data Collection"):
        s1 = Python("API Request Notebook")
        api = Server("Space X API v4")
        d1 = Storage("API Dataset")
        s1 >> api >> d1

    with Cluster("Web Scrapping"):
        s2 = Python("Web Scrapper Notebook")
        wikipedia = Server("Wikipedia")
        d2 = Storage("WebScrapping Dataset")
        s2 >> wikipedia >> d2

    d1 >> Edge(label="consolidate in") >> [d3]
    d2 >> Edge(label="consolidate in") >> [d3]
